# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Reading the input image
img = cv2.imread('mutual.png', 0)
kernel_size = 5
# Taking a matrix of size 5 as the kernel
kernel = np.ones((kernel_size,kernel_size), np.uint8)
 
# The first parameter is the original image,
# kernel is the matrix with which image is
# convolved and third parameter is the number
# of iterations, which will determine how much
# you want to erode/dilate a given image.
img_erosion = cv2.erode(img, kernel, iterations=1)
img_dilation = cv2.dilate(img, kernel, iterations=1)

# %%
fig,ax =plt.subplots(1,3,figsize=(20,30))
ax[0].imshow(img)
ax[1].imshow(img_erosion)
vmax = img.max()
vmin = img.min()
ax[2].imshow(img_erosion, vmax=vmax, vmin=vmin)

# %%
opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)

# %%
fig,ax =plt.subplots(1,2,figsize=(20,30))
ax[0].imshow(img)
ax[1].imshow(opening)

# %%
#thresholding
# Otsu's thresholding
ret2,th2 = cv2.threshold(img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
plt.imshow(th2)

# %%
kernel_size = 8
# Taking a matrix of size 5 as the kernel
kernel = np.ones((kernel_size,kernel_size), np.uint8)
img_erosion = cv2.erode(th2, kernel, iterations=1)
fig,ax =plt.subplots(1,2,figsize=(20,30))
ax[0].imshow(img)
ax[1].imshow(img_erosion)

# %%
#edges detection
img_edges = cv2.Canny(img,100,101)

# %%
plt.imshow(img_edges)

# %%
np.shape(img_edges)
# Out:
# (200, 200)

# %%
img_w_edges = img - img_edges

# %%
plt.imshow(img_w_edges)

# %%
#median blur
median = cv2.medianBlur(img, 5)
plt.imshow(median)

# %%
#other example
# Reading the input image
img = cv2.imread('mutual1.png', 0)
kernel_size = 15
# Taking a matrix of size 5 as the kernel
kernel = np.ones((kernel_size,kernel_size), np.uint8)
 
# The first parameter is the original image,
# kernel is the matrix with which image is
# convolved and third parameter is the number
# of iterations, which will determine how much
# you want to erode/dilate a given image.
img_erosion = cv2.erode(img, kernel, iterations=1)
img_dilation = cv2.dilate(img, kernel, iterations=1)

# %%
fig,ax =plt.subplots(1,3,figsize=(30,30))
ax[0].imshow(img)
ax[1].imshow(img_erosion)
vmax = img.max()
vmin = img.min()
ax[2].imshow(img_erosion, vmax=vmax, vmin=vmin)

# %%
#thresholding
# Otsu's thresholding
ret2,th2 = cv2.threshold(img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
plt.imshow(th2)
kernel_size = 4
# Taking a matrix of size 5 as the kernel
kernel = np.ones((kernel_size,kernel_size), np.uint8)
img_erosion = cv2.erode(th2, kernel, iterations=1)
fig,ax =plt.subplots(1,2,figsize=(20,30))
ax[0].imshow(img)
ax[1].imshow(img_erosion)

# %%
kernel_size = 5
# Taking a matrix of size 5 as the kernel
kernel = np.ones((kernel_size,kernel_size), np.uint8)
img_erosion = cv2.erode(img_erosion, kernel, iterations=1)
fig,ax =plt.subplots(1,2,figsize=(20,30))
ax[0].imshow(img)
ax[1].imshow(img_erosion)
